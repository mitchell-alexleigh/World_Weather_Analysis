# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=079f43442134212973786a277a29ecad

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_description = city_weather["name"]
        weather = city_weather["weather"]
        city_description = weather[0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | allapalli
# Processing Record 2 of Set 16 | marinette
# Processing Record 3 of Set 16 | new norfolk
# Processing Record 4 of Set 16 | jamestown
# Processing Record 5 of Set 16 | klaksvik
# Processing Record 6 of Set 16 | hilo
# Processing Record 7 of Set 16 | mukilteo
# Processing Record 8 of Set 16 | karlovo
# Processing Record 9 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 16 | karema
# Processing Record 11 of Set 16 | vaini
# Processing Record 12 of Set 16 | hobart
# Processing Record 13 of Set 16 | nikolskoye
# Processing Record 14 of Set 16 | rikitea
# Processing Record 15 of Set 16 | thompson
# Processing Record 16 of Set 16 | airai
# Processing Record 17 of Set 16 | willmar
# Processing Record 18 of Set 16 | kununurra
# Processing Record 19 of Set 16 | tuktoyaktuk
# Processing Record 20 of Set 16 | mar del plata
# ...

# %%
# Run an API request for each of the cities.
my_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=079f43442134212973786a277a29ecad&q=appleton"
# Parse the JSON and retrieve data.
city_weather = requests.get(my_url).json()

report = city_weather["weather"]
weather_description = report[0]['description']

weather_description
# Out:
# 'clear sky'

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
vacation_city_data_df = pd.DataFrame(city_data)
vacation_city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Allapalli  19.4167   80.0667     64.54        28          60        3.91
# 1    Marinette  45.1000  -87.6307     -5.80        71           1        9.22
# 2  New Norfolk -42.7826  147.0587     55.40        58          90        9.22
# 3    Jamestown  42.0970  -79.2353     21.00        86          90        9.22
# 4     Klaksvik  62.2266   -6.5890     33.80        86          40        5.75
# 5         Hilo  19.7297 -155.0900     64.40        59          20        8.05
# 6     Mukilteo  47.9445 -122.3046     39.99        87          75        3.44
# 7      Karlovo  42.6333   24.8000     48.00       100          90        2.30
# 8       Karema  -6.8205   30.4389     76.30        76          83        4.52
# 9        Vaini -21.2000 -175.2000     77.00        94          75       10.36
#
#   Country       Description
# 0      IN     broken clouds
# 1      US         clear sky
# ...

# %%
 new_column_order = ["City", "Country", "Description", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = vacation_city_data_df[new_column_order]
city_data_df
# Out:
#               City Country       Description      Lat       Lng  Max Temp  \
# 0        Allapalli      IN     broken clouds  19.4167   80.0667     64.54
# 1        Marinette      US         clear sky  45.1000  -87.6307     -5.80
# 2      New Norfolk      AU   overcast clouds -42.7826  147.0587     55.40
# 3        Jamestown      US        light snow  42.0970  -79.2353     21.00
# 4         Klaksvik      FO  scattered clouds  62.2266   -6.5890     33.80
# ..             ...     ...               ...      ...       ...       ...
# 739        Balabac      PH   overcast clouds   7.9868  117.0645     80.04
# 740  Belle Fourche      US        light snow  44.6714 -103.8522      5.00
# 741          Yatou      CN     broken clouds  37.1500  122.3833     28.15
# 742         Tanout      NE  scattered clouds  14.9709    8.8879     77.18
# 743       Edgewood      US        light rain  39.4187  -76.2944     35.01
#
#      Humidity  Cloudiness  Wind Speed
# 0          28          60        3.91
# ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the WeatherPy_Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
