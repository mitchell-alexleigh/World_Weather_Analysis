# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=079f43442134212973786a277a29ecad

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_description = city_weather["name"]
        weather = city_weather["weather"]
        city_description = weather[0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | dire
# Processing Record 2 of Set 16 | flinders
# Processing Record 3 of Set 16 | ushuaia
# Processing Record 4 of Set 16 | havelock
# Processing Record 5 of Set 16 | marsa matruh
# Processing Record 6 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 16 | saldanha
# Processing Record 8 of Set 16 | port alfred
# Processing Record 9 of Set 16 | mataura
# Processing Record 10 of Set 16 | kjollefjord
# Processing Record 11 of Set 16 | new norfolk
# Processing Record 12 of Set 16 | bengkulu
# Processing Record 13 of Set 16 | cape town
# Processing Record 14 of Set 16 | punta arenas
# Processing Record 15 of Set 16 | aklavik
# Processing Record 16 of Set 16 | east london
# Processing Record 17 of Set 16 | puerto gaitan
# Processing Record 18 of Set 16 | ponta do sol
# Processing Record 19 of Set 16 | geraldton
# Processing Record 20 of Set 16 | vaini
# Processing Record 21 of Set 16 | hami
# Processing Record 22 of Set 16 | atuona
# Processing Record 23 of Set 16 | morondava
# Processing Record 24 of Set 16 | tucuman
# Processing Record 25 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 16 | port elizabeth
# Processing Record 27 of Set 16 | busselton
# Processing Record 28 of Set 16 | stromness
# Processing Record 29 of Set 16 | elko
# Processing Record 30 of Set 16 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 16 | bluff
# Processing Record 32 of Set 16 | otjimbingwe
# Processing Record 33 of Set 16 | narsaq
# Processing Record 34 of Set 16 | port lincoln
# Processing Record 35 of Set 16 | wembley
# Processing Record 36 of Set 16 | mar del plata
# Processing Record 37 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 16 | alice springs
# Processing Record 39 of Set 16 | constitucion
# Processing Record 40 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 16 | nouadhibou
# Processing Record 42 of Set 16 | kapaa
# Processing Record 43 of Set 16 | west bay
# Processing Record 44 of Set 16 | butaritari
# Processing Record 45 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 16 | haines junction
# Processing Record 47 of Set 16 | puerto ayora
# Processing Record 48 of Set 16 | souillac
# Processing Record 49 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 16 | khatanga
# Processing Record 1 of Set 17 | vung tau
# Processing Record 2 of Set 17 | sur
# Processing Record 3 of Set 17 | cherskiy
# Processing Record 4 of Set 17 | tandil
# Processing Record 5 of Set 17 | seoul
# Processing Record 6 of Set 17 | indian head
# Processing Record 7 of Set 17 | fort myers beach
# Processing Record 8 of Set 17 | rikitea
# Processing Record 9 of Set 17 | mount gambier
# Processing Record 10 of Set 17 | kodiak
# Processing Record 11 of Set 17 | roma
# Processing Record 12 of Set 17 | barrow
# Processing Record 13 of Set 17 | mahebourg
# Processing Record 14 of Set 17 | pangnirtung
# Processing Record 15 of Set 17 | yulara
# Processing Record 16 of Set 17 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 17 | leh
# Processing Record 18 of Set 17 | katobu
# Processing Record 19 of Set 17 | yeppoon
# Processing Record 20 of Set 17 | bredasdorp
# Processing Record 21 of Set 17 | kidal
# Processing Record 22 of Set 17 | hasaki
# Processing Record 23 of Set 17 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 17 | thabazimbi
# Processing Record 25 of Set 17 | adrar
# Processing Record 26 of Set 17 | sinazongwe
# Processing Record 27 of Set 17 | sambava
# Processing Record 28 of Set 17 | mnogovershinnyy
# Processing Record 29 of Set 17 | mao
# Processing Record 30 of Set 17 | jalu
# Processing Record 31 of Set 17 | tilichiki
# Processing Record 32 of Set 17 | hermanus
# Processing Record 33 of Set 17 | farragut
# Processing Record 34 of Set 17 | san quintin
# Processing Record 35 of Set 17 | cabo san lucas
# Processing Record 36 of Set 17 | ulaangom
# Processing Record 37 of Set 17 | lovozero
# Processing Record 38 of Set 17 | bull savanna
# Processing Record 39 of Set 17 | kato mazarakion
# Processing Record 40 of Set 17 | albany
# Processing Record 41 of Set 17 | cidreira
# Processing Record 42 of Set 17 | klaksvik
# Processing Record 43 of Set 17 | alofi
# Processing Record 44 of Set 17 | jamestown
# Processing Record 45 of Set 17 | naze
# Processing Record 46 of Set 17 | northampton
# Processing Record 47 of Set 17 | huangnihe
# Processing Record 48 of Set 17 | puerto leguizamo
# Processing Record 49 of Set 17 | lebu
# Processing Record 50 of Set 17 | hobart
# Processing Record 1 of Set 18 | ostrovnoy
# Processing Record 2 of Set 18 | smithers
# Processing Record 3 of Set 18 | evensk
# Processing Record 4 of Set 18 | naruto
# Processing Record 5 of Set 18 | torbay
# Processing Record 6 of Set 18 | te anau
# Processing Record 7 of Set 18 | grindavik
# Processing Record 8 of Set 18 | teguise
# Processing Record 9 of Set 18 | chicama
# Processing Record 10 of Set 18 | tuktoyaktuk
# Processing Record 11 of Set 18 | saint-philippe
# Processing Record 12 of Set 18 | zhezkazgan
# Processing Record 13 of Set 18 | pevek
# Processing Record 14 of Set 18 | that phanom
# Processing Record 15 of Set 18 | hithadhoo
# Processing Record 16 of Set 18 | manta
# Processing Record 17 of Set 18 | malangali
# Processing Record 18 of Set 18 | salalah
# Processing Record 19 of Set 18 | camana
# Processing Record 20 of Set 18 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 18 | kuandian
# Processing Record 22 of Set 18 | qaanaaq
# Processing Record 23 of Set 18 | faya
# Processing Record 24 of Set 18 | labuhan
# Processing Record 25 of Set 18 | wufeng
# Processing Record 26 of Set 18 | guider
# Processing Record 27 of Set 18 | tingi
# Processing Record 28 of Set 18 | konitsa
# Processing Record 29 of Set 18 | karpathos
# Processing Record 30 of Set 18 | bata
# Processing Record 31 of Set 18 | chizhou
# Processing Record 32 of Set 18 | igarka
# Processing Record 33 of Set 18 | kadaya
# Processing Record 34 of Set 18 | great yarmouth
# Processing Record 35 of Set 18 | awbari
# Processing Record 36 of Set 18 | vidim
# Processing Record 37 of Set 18 | ribeira grande
# Processing Record 38 of Set 18 | inhambane
# Processing Record 39 of Set 18 | guerrero negro
# Processing Record 40 of Set 18 | ekhabi
# Processing Record 41 of Set 18 | nikolskoye
# Processing Record 42 of Set 18 | omboue
# Processing Record 43 of Set 18 | nyurba
# Processing Record 44 of Set 18 | faanui
# Processing Record 45 of Set 18 | provideniya
# Processing Record 46 of Set 18 | tuy hoa
# Processing Record 47 of Set 18 | berlevag
# Processing Record 48 of Set 18 | lata
# Processing Record 49 of Set 18 | chuy
# Processing Record 50 of Set 18 | batticaloa
# Processing Record 1 of Set 19 | airai
# Processing Record 2 of Set 19 | laguna
# Processing Record 3 of Set 19 | avarua
# Processing Record 4 of Set 19 | botou
# Processing Record 5 of Set 19 | leeds
# Processing Record 6 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 19 | esperance
# Processing Record 8 of Set 19 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 19 | lazo
# Processing Record 10 of Set 19 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 19 | byron bay
# Processing Record 12 of Set 19 | stornoway
# Processing Record 13 of Set 19 | bandar-e lengeh
# Processing Record 14 of Set 19 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 19 | college
# Processing Record 16 of Set 19 | porto santo
# Processing Record 17 of Set 19 | norman wells
# Processing Record 18 of Set 19 | georgetown
# Processing Record 19 of Set 19 | poum
# Processing Record 20 of Set 19 | tiksi
# Processing Record 21 of Set 19 | kimbe
# Processing Record 22 of Set 19 | chokurdakh
# Processing Record 23 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 19 | chenghai
# Processing Record 25 of Set 19 | muskegon
# Processing Record 26 of Set 19 | camacha
# Processing Record 27 of Set 19 | vanderhoof
# Processing Record 28 of Set 19 | alekseyevsk
# Processing Record 29 of Set 19 | fortuna
# Processing Record 30 of Set 19 | saint-francois
# Processing Record 31 of Set 19 | yellowknife
# Processing Record 32 of Set 19 | sunbury
# Processing Record 33 of Set 19 | labuan
# Processing Record 34 of Set 19 | tura
# Processing Record 35 of Set 19 | carutapera
# Processing Record 36 of Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 19 | walvis bay
# Processing Record 38 of Set 19 | dingle
# Processing Record 39 of Set 19 | arraial do cabo
# Processing Record 40 of Set 19 | upernavik
# Processing Record 41 of Set 19 | luderitz
# Processing Record 42 of Set 19 | san cristobal
# Processing Record 43 of Set 19 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 19 | leningradskiy
# Processing Record 45 of Set 19 | xihe
# Processing Record 46 of Set 19 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 19 | sidhi
# Processing Record 48 of Set 19 | port augusta
# Processing Record 49 of Set 19 | los llanos de aridane
# Processing Record 50 of Set 19 | hambantota
# Processing Record 1 of Set 20 | isangel
# Processing Record 2 of Set 20 | namibe
# Processing Record 3 of Set 20 | beira
# Processing Record 4 of Set 20 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 20 | praia da vitoria
# Processing Record 6 of Set 20 | port blair
# Processing Record 7 of Set 20 | palimbang
# Processing Record 8 of Set 20 | xinqing
# Processing Record 9 of Set 20 | mahajanga
# Processing Record 10 of Set 20 | vaxjo
# Processing Record 11 of Set 20 | ilulissat
# Processing Record 12 of Set 20 | waipawa
# Processing Record 13 of Set 20 | trairi
# Processing Record 14 of Set 20 | xining
# Processing Record 15 of Set 20 | kaitangata
# Processing Record 16 of Set 20 | hobyo
# Processing Record 17 of Set 20 | chongwe
# Processing Record 18 of Set 20 | marzuq
# Processing Record 19 of Set 20 | tautira
# Processing Record 20 of Set 20 | vostok
# Processing Record 21 of Set 20 | madhogarh
# Processing Record 22 of Set 20 | bambous virieux
# Processing Record 23 of Set 20 | elin pelin
# Processing Record 24 of Set 20 | mbini
# Processing Record 25 of Set 20 | hilo
# Processing Record 26 of Set 20 | nola
# Processing Record 27 of Set 20 | dikson
# Processing Record 28 of Set 20 | kishi
# Processing Record 29 of Set 20 | miri
# Processing Record 30 of Set 20 | amahai
# Processing Record 31 of Set 20 | sao filipe
# Processing Record 32 of Set 20 | gizo
# Processing Record 33 of Set 20 | paamiut
# Processing Record 34 of Set 20 | gat
# Processing Record 35 of Set 20 | nanortalik
# Processing Record 36 of Set 20 | kerema
# Processing Record 37 of Set 20 | toora-khem
# Processing Record 38 of Set 20 | hauterive
# Processing Record 39 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 20 | matamoros
# Processing Record 41 of Set 20 | gniezno
# Processing Record 42 of Set 20 | dalvik
# Processing Record 43 of Set 20 | ilobu
# Processing Record 44 of Set 20 | karratha
# Processing Record 45 of Set 20 | kudahuvadhoo
# Processing Record 46 of Set 20 | arya
# Processing Record 47 of Set 20 | paso de los toros
# Processing Record 48 of Set 20 | beirut
# Processing Record 49 of Set 20 | sao felix do xingu
# Processing Record 50 of Set 20 | ternate
# Processing Record 1 of Set 21 | songjianghe
# Processing Record 2 of Set 21 | port hedland
# Processing Record 3 of Set 21 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 21 | cayenne
# Processing Record 5 of Set 21 | gao
# Processing Record 6 of Set 21 | meadow lake
# Processing Record 7 of Set 21 | castro
# Processing Record 8 of Set 21 | bubaque
# Processing Record 9 of Set 21 | araxa
# Processing Record 10 of Set 21 | uray
# Processing Record 11 of Set 21 | itahari
# City not found. Skipping...
# Processing Record 12 of Set 21 | princeville
# Processing Record 13 of Set 21 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 21 | penzance
# Processing Record 15 of Set 21 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 16 of Set 21 | portland
# Processing Record 17 of Set 21 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 21 | tasiilaq
# Processing Record 19 of Set 21 | victoria
# Processing Record 20 of Set 21 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 21 | coihaique
# Processing Record 22 of Set 21 | arys
# Processing Record 23 of Set 21 | wad madani
# Processing Record 24 of Set 21 | abu samrah
# Processing Record 25 of Set 21 | quang ngai
# Processing Record 26 of Set 21 | camopi
# Processing Record 27 of Set 21 | ojinaga
# Processing Record 28 of Set 21 | goderich
# Processing Record 29 of Set 21 | las vegas
# Processing Record 30 of Set 21 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 21 | ucluelet
# Processing Record 32 of Set 21 | mombasa
# Processing Record 33 of Set 21 | ampanihy
# Processing Record 34 of Set 21 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 21 | vao
# Processing Record 36 of Set 21 | crotone
# Processing Record 37 of Set 21 | labe
# Processing Record 38 of Set 21 | anadyr
# Processing Record 39 of Set 21 | tarbes
# Processing Record 40 of Set 21 | champerico
# Processing Record 41 of Set 21 | oranjemund
# Processing Record 42 of Set 21 | srednekolymsk
# Processing Record 43 of Set 21 | galle
# Processing Record 44 of Set 21 | troy
# Processing Record 45 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 21 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 21 | san-pedro
# Processing Record 48 of Set 21 | taoudenni
# Processing Record 49 of Set 21 | tirlyanskiy
# Processing Record 50 of Set 21 | tyumentsevo
# Processing Record 1 of Set 22 | bridgetown
# Processing Record 2 of Set 22 | severo-kurilsk
# Processing Record 3 of Set 22 | dunedin
# Processing Record 4 of Set 22 | lavrentiya
# Processing Record 5 of Set 22 | thompson
# Processing Record 6 of Set 22 | bethel
# Processing Record 7 of Set 22 | salinas
# Processing Record 8 of Set 22 | galesong
# Processing Record 9 of Set 22 | lokachi
# Processing Record 10 of Set 22 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 22 | nayoro
# Processing Record 12 of Set 22 | santa isabel do rio negro
# Processing Record 13 of Set 22 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 22 | tuatapere
# Processing Record 15 of Set 22 | tabas
# Processing Record 16 of Set 22 | bonfim
# Processing Record 17 of Set 22 | sherlovaya gora
# Processing Record 18 of Set 22 | mendoza
# Processing Record 19 of Set 22 | alamosa
# Processing Record 20 of Set 22 | vila velha
# Processing Record 21 of Set 22 | soavinandriana
# Processing Record 22 of Set 22 | saint george
# Processing Record 23 of Set 22 | eirunepe
# Processing Record 24 of Set 22 | ponta delgada
# Processing Record 25 of Set 22 | grand gaube
# Processing Record 26 of Set 22 | bonavista
# Processing Record 27 of Set 22 | waingapu
# Processing Record 28 of Set 22 | kalmunai
# Processing Record 29 of Set 22 | rocha
# Processing Record 30 of Set 22 | thiadiaye
# Processing Record 31 of Set 22 | beloha
# Processing Record 32 of Set 22 | xuddur
# Processing Record 33 of Set 22 | rantepao
# Processing Record 34 of Set 22 | gabu
# Processing Record 35 of Set 22 | floro
# Processing Record 36 of Set 22 | santiago del estero
# Processing Record 37 of Set 22 | grao mogol
# Processing Record 38 of Set 22 | remedios
# Processing Record 39 of Set 22 | bogovarovo
# Processing Record 40 of Set 22 | sotouboua
# Processing Record 41 of Set 22 | sitka
# Processing Record 42 of Set 22 | little current
# Processing Record 43 of Set 22 | clyde river
# Processing Record 44 of Set 22 | inuvik
# Processing Record 45 of Set 22 | moree
# Processing Record 46 of Set 22 | likhoslavl
# Processing Record 47 of Set 22 | biltine
# Processing Record 48 of Set 22 | karaton
# Processing Record 49 of Set 22 | san patricio
# Processing Record 50 of Set 22 | daru
# Processing Record 1 of Set 23 | santiago tuxtla
# Processing Record 2 of Set 23 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 23 | lagoa
# Processing Record 4 of Set 23 | mizdah
# Processing Record 5 of Set 23 | longyearbyen
# Processing Record 6 of Set 23 | zapolyarnyy
# Processing Record 7 of Set 23 | culebra
# Processing Record 8 of Set 23 | jacqueville
# Processing Record 9 of Set 23 | ixtapa
# Processing Record 10 of Set 23 | gander
# Processing Record 11 of Set 23 | kavieng
# Processing Record 12 of Set 23 | cockburn town
# Processing Record 13 of Set 23 | noumea
# Processing Record 14 of Set 23 | egvekinot
# Processing Record 15 of Set 23 | lagunas
# Processing Record 16 of Set 23 | santa fe
# Processing Record 17 of Set 23 | shatrovo
# Processing Record 18 of Set 23 | illapel
# Processing Record 19 of Set 23 | locri
# Processing Record 20 of Set 23 | lasa
# Processing Record 21 of Set 23 | butembo
# Processing Record 22 of Set 23 | broome
# Processing Record 23 of Set 23 | ust-kuyga
# Processing Record 24 of Set 23 | ak-dovurak
# Processing Record 25 of Set 23 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 23 | adre
# Processing Record 27 of Set 23 | teixoso
# Processing Record 28 of Set 23 | fairbanks
# Processing Record 29 of Set 23 | nelson bay
# Processing Record 30 of Set 23 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 23 | plouzane
# Processing Record 32 of Set 23 | jaisalmer
# Processing Record 33 of Set 23 | mariestad
# Processing Record 34 of Set 23 | batagay-alyta
# Processing Record 35 of Set 23 | nuuk
# Processing Record 36 of Set 23 | fontem
# Processing Record 37 of Set 23 | ketchikan
# Processing Record 38 of Set 23 | umm kaddadah
# Processing Record 39 of Set 23 | la ronge
# Processing Record 40 of Set 23 | pando
# Processing Record 41 of Set 23 | poso
# Processing Record 42 of Set 23 | honiara
# Processing Record 43 of Set 23 | waw
# Processing Record 44 of Set 23 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 23 | trinidad
# Processing Record 46 of Set 23 | huinan
# Processing Record 47 of Set 23 | tamahu
# Processing Record 48 of Set 23 | lalomanu
# City not found. Skipping...
# Processing Record 49 of Set 23 | la sarre
# Processing Record 50 of Set 23 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 24 | vila franca do campo
# Processing Record 2 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 24 | richards bay
# Processing Record 4 of Set 24 | katsuura
# Processing Record 5 of Set 24 | gadsden
# Processing Record 6 of Set 24 | staryy nadym
# Processing Record 7 of Set 24 | pisco
# Processing Record 8 of Set 24 | jurm
# Processing Record 9 of Set 24 | siocon
# Processing Record 10 of Set 24 | makasar
# Processing Record 11 of Set 24 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 24 | cap-aux-meules
# Processing Record 13 of Set 24 | san carlos de bariloche
# Processing Record 14 of Set 24 | mananjary
# Processing Record 15 of Set 24 | tres arroyos
# Processing Record 16 of Set 24 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 24 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 24 | nome
# Processing Record 19 of Set 24 | narasannapeta
# Processing Record 20 of Set 24 | catuday
# Processing Record 21 of Set 24 | bor
# Processing Record 22 of Set 24 | kumano
# Processing Record 23 of Set 24 | coyah
# Processing Record 24 of Set 24 | mecca
# Processing Record 25 of Set 24 | pratapgarh
# Processing Record 26 of Set 24 | tankhoy
# Processing Record 27 of Set 24 | mayma
# Processing Record 28 of Set 24 | port-gentil
# Processing Record 29 of Set 24 | kiama
# Processing Record 30 of Set 24 | prince albert
# Processing Record 31 of Set 24 | rio grande
# Processing Record 32 of Set 24 | conceicao da barra
# Processing Record 33 of Set 24 | aleksandrovka
# Processing Record 34 of Set 24 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 24 | teguldet
# Processing Record 36 of Set 24 | gorele
# Processing Record 37 of Set 24 | codrington
# Processing Record 38 of Set 24 | kalamata
# Processing Record 39 of Set 24 | avera
# Processing Record 40 of Set 24 | sorland
# Processing Record 41 of Set 24 | itarema
# Processing Record 42 of Set 24 | karmana
# City not found. Skipping...
# Processing Record 43 of Set 24 | okha
# Processing Record 44 of Set 24 | mazagao
# Processing Record 45 of Set 24 | saskylakh
# Processing Record 46 of Set 24 | necochea
# Processing Record 47 of Set 24 | chivay
# Processing Record 48 of Set 24 | nabire
# Processing Record 49 of Set 24 | sola
# Processing Record 50 of Set 24 | zhanaozen
# Processing Record 1 of Set 25 | comodoro rivadavia
# Processing Record 2 of Set 25 | warri
# Processing Record 3 of Set 25 | tutayev
# Processing Record 4 of Set 25 | cairns
# Processing Record 5 of Set 25 | lethem
# Processing Record 6 of Set 25 | ambovombe
# Processing Record 7 of Set 25 | sao joao da barra
# Processing Record 8 of Set 25 | carnarvon
# Processing Record 9 of Set 25 | havre-saint-pierre
# Processing Record 10 of Set 25 | komsomolskiy
# Processing Record 11 of Set 25 | chara
# Processing Record 12 of Set 25 | la rioja
# Processing Record 13 of Set 25 | megion
# Processing Record 14 of Set 25 | novobirilyussy
# Processing Record 15 of Set 25 | kruisfontein
# Processing Record 16 of Set 25 | ligayan
# Processing Record 17 of Set 25 | manresa
# Processing Record 18 of Set 25 | bilma
# Processing Record 19 of Set 25 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 25 | taywarah
# Processing Record 21 of Set 25 | borogontsy
# Processing Record 22 of Set 25 | kysyl-syr
# Processing Record 23 of Set 25 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 25 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 25 | kralendijk
# Processing Record 26 of Set 25 | beberibe
# Processing Record 27 of Set 25 | andenes
# Processing Record 28 of Set 25 | broken hill
# Processing Record 29 of Set 25 | ilo
# Processing Record 30 of Set 25 | xinyu
# Processing Record 31 of Set 25 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 25 | ukwa
# Processing Record 33 of Set 25 | antofagasta
# Processing Record 34 of Set 25 | durusu
# Processing Record 35 of Set 25 | aksay
# Processing Record 36 of Set 25 | nikolayevsk-na-amure
# Processing Record 37 of Set 25 | buala
# Processing Record 38 of Set 25 | tessalit
# Processing Record 39 of Set 25 | pechora
# Processing Record 40 of Set 25 | tonj
# Processing Record 41 of Set 25 | buta
# Processing Record 42 of Set 25 | podyuga
# Processing Record 43 of Set 25 | ust-nera
# Processing Record 44 of Set 25 | santa cruz
# Processing Record 45 of Set 25 | sisimiut
# Processing Record 46 of Set 25 | atar
# Processing Record 47 of Set 25 | takoradi
# Processing Record 48 of Set 25 | xinmin
# Processing Record 49 of Set 25 | ouagadougou
# Processing Record 50 of Set 25 | talakan
# Processing Record 1 of Set 26 | villa carlos paz
# Processing Record 2 of Set 26 | jacareacanga
# Processing Record 3 of Set 26 | anito
# Processing Record 4 of Set 26 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 26 | colonial heights
# Processing Record 6 of Set 26 | pelym
# Processing Record 7 of Set 26 | qasigiannguit
# Processing Record 8 of Set 26 | orocue
# Processing Record 9 of Set 26 | alindao
# Processing Record 10 of Set 26 | babu
# Processing Record 11 of Set 26 | phan thiet
# Processing Record 12 of Set 26 | lucatan
# City not found. Skipping...
# Processing Record 13 of Set 26 | spokoynaya
# Processing Record 14 of Set 26 | lorengau
# Processing Record 15 of Set 26 | kuyanovo
# Processing Record 16 of Set 26 | peniche
# Processing Record 17 of Set 26 | general roca
# Processing Record 18 of Set 26 | ahipara
# Processing Record 19 of Set 26 | kyren
# Processing Record 20 of Set 26 | maltahohe
# Processing Record 21 of Set 26 | shingu
# Processing Record 22 of Set 26 | rorvik
# Processing Record 23 of Set 26 | the pas
# Processing Record 24 of Set 26 | porto novo
# Processing Record 25 of Set 26 | laplace
# Processing Record 26 of Set 26 | kirakira
# Processing Record 27 of Set 26 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 26 | ugoofaaru
# Processing Record 29 of Set 26 | manali
# Processing Record 30 of Set 26 | pacific grove
# Processing Record 31 of Set 26 | black diamond
# Processing Record 32 of Set 26 | strenci
# Processing Record 33 of Set 26 | taos
# Processing Record 34 of Set 26 | fortuna foothills
# Processing Record 35 of Set 26 | sobolevo
# Processing Record 36 of Set 26 | marv dasht
# City not found. Skipping...
# Processing Record 37 of Set 26 | touros
# Processing Record 38 of Set 26 | maxixe
# Processing Record 39 of Set 26 | manjacaze
# Processing Record 40 of Set 26 | boda
# Processing Record 41 of Set 26 | fuengirola
# Processing Record 42 of Set 26 | kaduna
# Processing Record 43 of Set 26 | kozhva
# Processing Record 44 of Set 26 | vastervik
# City not found. Skipping...
# Processing Record 45 of Set 26 | nizhneudinsk
# Processing Record 46 of Set 26 | vaitape
# Processing Record 47 of Set 26 | kavali
# Processing Record 48 of Set 26 | qeshm
# Processing Record 49 of Set 26 | viedma
# Processing Record 50 of Set 26 | nicoya
# Processing Record 1 of Set 27 | teya
# Processing Record 2 of Set 27 | bathsheba
# Processing Record 3 of Set 27 | puerto carreno
# Processing Record 4 of Set 27 | fairview
# Processing Record 5 of Set 27 | yaan
# Processing Record 6 of Set 27 | saint-augustin
# Processing Record 7 of Set 27 | anloga
# Processing Record 8 of Set 27 | laramie
# Processing Record 9 of Set 27 | chenzhou
# Processing Record 10 of Set 27 | oktyabrskiy
# Processing Record 11 of Set 27 | jatai
# Processing Record 12 of Set 27 | kanigoro
# Processing Record 13 of Set 27 | hachinohe
# Processing Record 14 of Set 27 | arlit
# Processing Record 15 of Set 27 | tondano
# Processing Record 16 of Set 27 | bulgan
# Processing Record 17 of Set 27 | taft
# Processing Record 18 of Set 27 | deputatskiy
# Processing Record 19 of Set 27 | benguela
# Processing Record 20 of Set 27 | nishihara
# Processing Record 21 of Set 27 | belle fourche
# Processing Record 22 of Set 27 | sept-iles
# Processing Record 23 of Set 27 | corralillo
# Processing Record 24 of Set 27 | rondonopolis
# Processing Record 25 of Set 27 | taltal
# Processing Record 26 of Set 27 | addi ugri
# City not found. Skipping...
# Processing Record 27 of Set 27 | asau
# Processing Record 28 of Set 27 | okato
# Processing Record 29 of Set 27 | akonolinga
# Processing Record 30 of Set 27 | belyy yar
# Processing Record 31 of Set 27 | kang
# Processing Record 32 of Set 27 | we
# City not found. Skipping...
# Processing Record 33 of Set 27 | kroya
# Processing Record 34 of Set 27 | abu road
# Processing Record 35 of Set 27 | slave lake
# Processing Record 36 of Set 27 | ginir
# Processing Record 37 of Set 27 | plettenberg bay
# Processing Record 38 of Set 27 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 27 | kesan
# Processing Record 40 of Set 27 | puerto palomas
# Processing Record 41 of Set 27 | walsrode
# Processing Record 42 of Set 27 | talnakh
# Processing Record 43 of Set 27 | beringovskiy
# Processing Record 44 of Set 27 | ndouci
# City not found. Skipping...
# Processing Record 45 of Set 27 | ancud
# Processing Record 46 of Set 27 | seydi
# Processing Record 47 of Set 27 | didao
# Processing Record 48 of Set 27 | alta floresta
# Processing Record 49 of Set 27 | thohoyandou
# Processing Record 50 of Set 27 | totskoye
# Processing Record 1 of Set 28 | mehamn
# Processing Record 2 of Set 28 | brewster
# Processing Record 3 of Set 28 | ekibastuz
# Processing Record 4 of Set 28 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 28 | plessisville
# Processing Record 6 of Set 28 | yerbogachen
# Processing Record 7 of Set 28 | mudon
# Processing Record 8 of Set 28 | cieza
# Processing Record 9 of Set 28 | manthani
# Processing Record 10 of Set 28 | huangzhou
# Processing Record 11 of Set 28 | quincy
# Processing Record 12 of Set 28 | kavaratti
# Processing Record 13 of Set 28 | cabedelo
# Processing Record 14 of Set 28 | kaeo
# Processing Record 15 of Set 28 | ascension
# Processing Record 16 of Set 28 | sukhoy log
# Processing Record 17 of Set 28 | farmington
# Processing Record 18 of Set 28 | mamallapuram
# Processing Record 19 of Set 28 | adelaide
# Processing Record 20 of Set 28 | gidam
# Processing Record 21 of Set 28 | iqaluit
# Processing Record 22 of Set 28 | lulea
# Processing Record 23 of Set 28 | appleton
# Processing Record 24 of Set 28 | bandarbeyla
# Processing Record 25 of Set 28 | dubuque
# Processing Record 26 of Set 28 | coquimbo
# Processing Record 27 of Set 28 | vardo
# Processing Record 28 of Set 28 | zuwarah
# Processing Record 29 of Set 28 | dianopolis
# City not found. Skipping...
# Processing Record 30 of Set 28 | leshukonskoye
# Processing Record 31 of Set 28 | vestmannaeyjar
# Processing Record 32 of Set 28 | lotoshino
# Processing Record 33 of Set 28 | port macquarie
# Processing Record 34 of Set 28 | severo-yeniseyskiy
# Processing Record 35 of Set 28 | jiazi
# Processing Record 36 of Set 28 | lompoc
# Processing Record 37 of Set 28 | junction city
# Processing Record 38 of Set 28 | tiarei
# Processing Record 39 of Set 28 | parrita
# Processing Record 40 of Set 28 | lincoln
# Processing Record 41 of Set 28 | jati
# Processing Record 42 of Set 28 | roald
# Processing Record 43 of Set 28 | oneida
# Processing Record 44 of Set 28 | tumut
# Processing Record 45 of Set 28 | serenje
# Processing Record 46 of Set 28 | phalodi
# Processing Record 47 of Set 28 | wakkanai
# Processing Record 48 of Set 28 | price
# Processing Record 49 of Set 28 | itaituba
# Processing Record 50 of Set 28 | the valley
# Processing Record 1 of Set 29 | yar-sale
# Processing Record 2 of Set 29 | chadiza
# Processing Record 3 of Set 29 | sangar
# Processing Record 4 of Set 29 | diu
# Processing Record 5 of Set 29 | mariveles
# Processing Record 6 of Set 29 | gumdag
# Processing Record 7 of Set 29 | mahibadhoo
# Processing Record 8 of Set 29 | panjab
# Processing Record 9 of Set 29 | atasu
# Processing Record 10 of Set 29 | sangmelima
# Processing Record 11 of Set 29 | mariental
# Processing Record 12 of Set 29 | gallup
# Processing Record 13 of Set 29 | manzhouli
# Processing Record 14 of Set 29 | saiki
# Processing Record 15 of Set 29 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 29 | along
# Processing Record 17 of Set 29 | bahia blanca
# Processing Record 18 of Set 29 | mbandaka
# Processing Record 19 of Set 29 | aksarka
# Processing Record 20 of Set 29 | ayagoz
# Processing Record 21 of Set 29 | atambua
# Processing Record 22 of Set 29 | margate
# Processing Record 23 of Set 29 | morant bay
# Processing Record 24 of Set 29 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 29 | fort nelson
# Processing Record 26 of Set 29 | puerto del rosario
# Processing Record 27 of Set 29 | astakos
# Processing Record 28 of Set 29 | conceicao do almeida
# Processing Record 29 of Set 29 | dawei
# Processing Record 30 of Set 29 | siparia
# Processing Record 31 of Set 29 | kathu
# Processing Record 32 of Set 29 | bartica
# Processing Record 33 of Set 29 | shizunai
# Processing Record 34 of Set 29 | quatre cocos
# Processing Record 35 of Set 29 | azimur
# City not found. Skipping...
# Processing Record 36 of Set 29 | maun
# Processing Record 37 of Set 29 | dali
# Processing Record 38 of Set 29 | namtsy
# Processing Record 39 of Set 29 | kabare
# Processing Record 40 of Set 29 | mayor pablo lagerenza
# Processing Record 41 of Set 29 | luziania
# Processing Record 42 of Set 29 | abu dhabi
# Processing Record 43 of Set 29 | wasilla
# Processing Record 44 of Set 29 | bracebridge
# Processing Record 45 of Set 29 | alekseyevka
# Processing Record 46 of Set 29 | mehran
# Processing Record 47 of Set 29 | manaus
# Processing Record 48 of Set 29 | sioux lookout
# Processing Record 49 of Set 29 | dudinka
# Processing Record 50 of Set 29 | sibolga
# Processing Record 1 of Set 30 | shelburne
# Processing Record 2 of Set 30 | kamenka
# Processing Record 3 of Set 30 | kushmurun
# Processing Record 4 of Set 30 | senanga
# Processing Record 5 of Set 30 | acarau
# Processing Record 6 of Set 30 | portel
# Processing Record 7 of Set 30 | san vicente
# Processing Record 8 of Set 30 | shimoda
# Processing Record 9 of Set 30 | veraval
# Processing Record 10 of Set 30 | kahului
# Processing Record 11 of Set 30 | saint anthony
# Processing Record 12 of Set 30 | griffith
# Processing Record 13 of Set 30 | bystryy istok
# Processing Record 14 of Set 30 | kumo
# Processing Record 15 of Set 30 | kumla
# Processing Record 16 of Set 30 | sinnamary
# Processing Record 17 of Set 30 | kamiiso
# Processing Record 18 of Set 30 | kokopo
# Processing Record 19 of Set 30 | baykit
# Processing Record 20 of Set 30 | kondol
# Processing Record 21 of Set 30 | sungai siput utara
# City not found. Skipping...
# Processing Record 22 of Set 30 | malakal
# Processing Record 23 of Set 30 | dzilam gonzalez
# Processing Record 24 of Set 30 | abalak
# Processing Record 25 of Set 30 | alamos
# Processing Record 26 of Set 30 | krasnoselkup
# Processing Record 27 of Set 30 | abeche
# Processing Record 28 of Set 30 | saint-pierre
# Processing Record 29 of Set 30 | yarmouth
# Processing Record 30 of Set 30 | kholtoson
# Processing Record 31 of Set 30 | ilhabela
# Processing Record 32 of Set 30 | lagos
# Processing Record 33 of Set 30 | linfen
# Processing Record 34 of Set 30 | salihorsk
# Processing Record 35 of Set 30 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 30 | bacuit
# City not found. Skipping...
# Processing Record 37 of Set 30 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 30 | eyl
# Processing Record 39 of Set 30 | chalette-sur-loing
# Processing Record 40 of Set 30 | kitimat
# Processing Record 41 of Set 30 | urfa
# City not found. Skipping...
# Processing Record 42 of Set 30 | yarada
# Processing Record 43 of Set 30 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 30 | verkhnevilyuysk
# Processing Record 45 of Set 30 | minab
# Processing Record 46 of Set 30 | aripuana
# Processing Record 47 of Set 30 | manbij
# Processing Record 48 of Set 30 | tual
# Processing Record 49 of Set 30 | charlestown
# Processing Record 50 of Set 30 | stawell
# Processing Record 1 of Set 31 | mamakan
# Processing Record 2 of Set 31 | severomuysk
# Processing Record 3 of Set 31 | garowe
# Processing Record 4 of Set 31 | sansai
# City not found. Skipping...
# Processing Record 5 of Set 31 | killam
# Processing Record 6 of Set 31 | graciano sanchez
# Processing Record 7 of Set 31 | gravdal
# Processing Record 8 of Set 31 | wanaka
# Processing Record 9 of Set 31 | russell
# Processing Record 10 of Set 31 | orcopampa
# Processing Record 11 of Set 31 | raudeberg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Run an API request for each of the cities.
my_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=079f43442134212973786a277a29ecad&q=appleton"
# Parse the JSON and retrieve data.
city_weather = requests.get(my_url).json()

report = city_weather["weather"]
weather_description = report[0]['description']

weather_description
# Out:
# 'broken clouds'

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
vacation_city_data_df = pd.DataFrame(city_data)
vacation_city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dire  12.2833  -10.9667     72.18        20          22
# 1      Flinders -34.5833  150.8552     82.99        65          46
# 2       Ushuaia -54.8000  -68.3000     51.80        62          75
# 3      Havelock  34.8791  -76.9013     41.00        42           1
# 4  Marsa Matruh  31.3525   27.2453     60.80        88          40
# 5      Saldanha -33.0117   17.9442     62.60        82           6
# 6   Port Alfred -33.5906   26.8910     70.00        91          38
# 7       Mataura -46.1927  168.8643     65.77        32           0
# 8   Kjollefjord  70.9457   27.3465     29.10        93         100
# 9   New Norfolk -42.7826  147.0587     73.00        56          94
#
#    Wind Speed Country   Description
# 0        1.10      ML          Diré
# 1        5.99      AU      Flinders
# 2        8.05      AR       Ushuaia
# 3        9.22      US      Havelock
# 4       11.50      EG  Marsá Maţrūḩ
# 5        5.75      ZA      Saldanha
# 6        1.99      ZA   Port Alfred
# 7        8.30      NZ       Mataura
# 8       22.32      NO   Kjøllefjord
# 9        4.00      AU   New Norfolk

# %%
 new_column_order = ["City", "Country", "Description", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
vacation_city_data_df = vacation_city_data_df[new_column_order]
vacation_city_data_df
# Out:
#              City Country   Description      Lat       Lng  Max Temp  \
# 0            Dire      ML          Diré  12.2833  -10.9667     72.18
# 1        Flinders      AU      Flinders -34.5833  150.8552     82.99
# 2         Ushuaia      AR       Ushuaia -54.8000  -68.3000     51.80
# 3        Havelock      US      Havelock  34.8791  -76.9013     41.00
# 4    Marsa Matruh      EG  Marsá Maţrūḩ  31.3525   27.2453     60.80
# ..            ...     ...           ...      ...       ...       ...
# 688       Gravdal      NO       Gravdal  68.1214   13.5031     33.30
# 689        Wanaka      NZ        Wanaka -44.7000  169.1500     64.76
# 690       Russell      US       Russell  32.3502  -85.1999     44.60
# 691     Orcopampa      PE     Orcopampa -15.2661  -72.3417     46.00
# 692     Raudeberg      NO     Raudeberg  61.9875    5.1352     23.00
#
#      Humidity  Cloudiness  Wind Speed
# 0          20          22        1.10
# 1          65          46        5.99
# 2          62          75        8.05
# 3          42           1        9.22
# 4          88          40       11.50
# ..        ...         ...         ...
# 688        85          99       22.64
# 689        55          69        4.27
# 690        60           1        4.16
# 691        70         100        1.92
# 692        74           0        9.22
#
# [693 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Vacation_cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6c4d227522d9> in <module>
#       2 output_data_file = "Vacation_cities.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# NameError: name 'city_data_df' is not defined
