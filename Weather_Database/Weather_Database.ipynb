# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=079f43442134212973786a277a29ecad

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_description = city_weather["name"]
        weather = city_weather["weather"]
        city_description = weather[0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | kavaratti
# Processing Record 2 of Set 16 | emirdag
# Processing Record 3 of Set 16 | arraial do cabo
# Processing Record 4 of Set 16 | roberto payan
# City not found. Skipping...
# Processing Record 5 of Set 16 | barrow
# Processing Record 6 of Set 16 | rikitea
# Processing Record 7 of Set 16 | belogorsk
# Processing Record 8 of Set 16 | albany
# Processing Record 9 of Set 16 | hilo
# Processing Record 10 of Set 16 | port elizabeth
# Processing Record 11 of Set 16 | ushuaia
# Processing Record 12 of Set 16 | guerrero negro
# Processing Record 13 of Set 16 | port alfred
# Processing Record 14 of Set 16 | fitjar
# Processing Record 15 of Set 16 | goure
# Processing Record 16 of Set 16 | dovolnoye
# Processing Record 17 of Set 16 | punta arenas
# Processing Record 18 of Set 16 | qaanaaq
# Processing Record 19 of Set 16 | mysliborz
# Processing Record 20 of Set 16 | bredasdorp
# Processing Record 21 of Set 16 | ilulissat
# Processing Record 22 of Set 16 | chuy
# Processing Record 23 of Set 16 | mayumba
# Processing Record 24 of Set 16 | hasaki
# Processing Record 25 of Set 16 | yellowknife
# Processing Record 26 of Set 16 | salalah
# Processing Record 27 of Set 16 | hermanus
# Processing Record 28 of Set 16 | clyde river
# Processing Record 29 of Set 16 | estelle
# Processing Record 30 of Set 16 | maicao
# Processing Record 31 of Set 16 | busselton
# Processing Record 32 of Set 16 | mataura
# Processing Record 33 of Set 16 | castro
# Processing Record 34 of Set 16 | anadyr
# Processing Record 35 of Set 16 | ust-nera
# Processing Record 36 of Set 16 | hithadhoo
# Processing Record 37 of Set 16 | las vegas
# Processing Record 38 of Set 16 | cape town
# Processing Record 39 of Set 16 | shihezi
# Processing Record 40 of Set 16 | new norfolk
# Processing Record 41 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 16 | gornopravdinsk
# Processing Record 43 of Set 16 | avarua
# Processing Record 44 of Set 16 | adrar
# Processing Record 45 of Set 16 | hingoli
# Processing Record 46 of Set 16 | grindavik
# Processing Record 47 of Set 16 | saint-philippe
# Processing Record 48 of Set 16 | pangnirtung
# Processing Record 49 of Set 16 | carnarvon
# Processing Record 50 of Set 16 | victoria
# Processing Record 1 of Set 17 | jerome
# Processing Record 2 of Set 17 | iqaluit
# Processing Record 3 of Set 17 | mangaratiba
# Processing Record 4 of Set 17 | tiznit
# Processing Record 5 of Set 17 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 17 | sitka
# Processing Record 7 of Set 17 | port-cartier
# Processing Record 8 of Set 17 | veraval
# Processing Record 9 of Set 17 | avera
# Processing Record 10 of Set 17 | pitimbu
# Processing Record 11 of Set 17 | khatanga
# Processing Record 12 of Set 17 | beringovskiy
# Processing Record 13 of Set 17 | bethel
# Processing Record 14 of Set 17 | bengkulu
# Processing Record 15 of Set 17 | bestobe
# Processing Record 16 of Set 17 | koutsouras
# Processing Record 17 of Set 17 | trogir
# Processing Record 18 of Set 17 | hovd
# Processing Record 19 of Set 17 | nantucket
# Processing Record 20 of Set 17 | severodvinsk
# Processing Record 21 of Set 17 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 17 | noumea
# Processing Record 23 of Set 17 | na wa
# Processing Record 24 of Set 17 | san carlos de bariloche
# Processing Record 25 of Set 17 | kremenchuk
# Processing Record 26 of Set 17 | la macarena
# Processing Record 27 of Set 17 | mar del plata
# Processing Record 28 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 17 | chimbote
# Processing Record 30 of Set 17 | dikson
# Processing Record 31 of Set 17 | butaritari
# Processing Record 32 of Set 17 | little baguio
# Processing Record 33 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 17 | los llanos de aridane
# Processing Record 35 of Set 17 | praia da vitoria
# Processing Record 36 of Set 17 | katsuura
# Processing Record 37 of Set 17 | jamestown
# Processing Record 38 of Set 17 | fortuna
# Processing Record 39 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 17 | dingle
# Processing Record 41 of Set 17 | katherine
# Processing Record 42 of Set 17 | haines junction
# Processing Record 43 of Set 17 | vuktyl
# Processing Record 44 of Set 17 | taltal
# Processing Record 45 of Set 17 | vaini
# Processing Record 46 of Set 17 | bluff
# Processing Record 47 of Set 17 | komsomolskiy
# Processing Record 48 of Set 17 | tuktoyaktuk
# Processing Record 49 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 17 | edeia
# Processing Record 1 of Set 18 | thompson
# Processing Record 2 of Set 18 | harsud
# Processing Record 3 of Set 18 | severo-kurilsk
# Processing Record 4 of Set 18 | san jeronimo
# Processing Record 5 of Set 18 | portland
# Processing Record 6 of Set 18 | vestmannaeyjar
# Processing Record 7 of Set 18 | saskylakh
# Processing Record 8 of Set 18 | mount isa
# Processing Record 9 of Set 18 | raudeberg
# Processing Record 10 of Set 18 | socota
# Processing Record 11 of Set 18 | kirakira
# Processing Record 12 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 18 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 18 | hauge
# Processing Record 15 of Set 18 | tuatapere
# Processing Record 16 of Set 18 | mahebourg
# Processing Record 17 of Set 18 | yulin
# Processing Record 18 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 18 | gravdal
# Processing Record 20 of Set 18 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 18 | gulabpura
# Processing Record 23 of Set 18 | hibbing
# Processing Record 24 of Set 18 | lagoa
# Processing Record 25 of Set 18 | tasiilaq
# Processing Record 26 of Set 18 | bilma
# Processing Record 27 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 18 | rio gallegos
# Processing Record 29 of Set 18 | hokitika
# Processing Record 30 of Set 18 | labe
# Processing Record 31 of Set 18 | pundaguitan
# Processing Record 32 of Set 18 | ribeira grande
# Processing Record 33 of Set 18 | baie du tombeau
# City not found. Skipping...
# Processing Record 34 of Set 18 | srednekolymsk
# Processing Record 35 of Set 18 | oranjestad
# Processing Record 36 of Set 18 | pouembout
# Processing Record 37 of Set 18 | sorland
# Processing Record 38 of Set 18 | yvetot
# Processing Record 39 of Set 18 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 18 | olafsvik
# Processing Record 41 of Set 18 | port keats
# Processing Record 42 of Set 18 | kahului
# Processing Record 43 of Set 18 | yarke pole
# Processing Record 44 of Set 18 | kieta
# Processing Record 45 of Set 18 | east london
# Processing Record 46 of Set 18 | tautira
# Processing Record 47 of Set 18 | paso de los toros
# Processing Record 48 of Set 18 | hoyanger
# Processing Record 49 of Set 18 | leningradskiy
# Processing Record 50 of Set 18 | ponta do sol
# Processing Record 1 of Set 19 | port-gentil
# Processing Record 2 of Set 19 | atlantic city
# Processing Record 3 of Set 19 | abu samrah
# Processing Record 4 of Set 19 | broome
# Processing Record 5 of Set 19 | hualmay
# Processing Record 6 of Set 19 | lebu
# Processing Record 7 of Set 19 | yerkoy
# Processing Record 8 of Set 19 | kapaa
# Processing Record 9 of Set 19 | vao
# Processing Record 10 of Set 19 | faya
# Processing Record 11 of Set 19 | coihaique
# Processing Record 12 of Set 19 | jambi
# Processing Record 13 of Set 19 | buenos aires
# Processing Record 14 of Set 19 | bambous virieux
# Processing Record 15 of Set 19 | matamoros
# Processing Record 16 of Set 19 | inirida
# Processing Record 17 of Set 19 | airai
# Processing Record 18 of Set 19 | upernavik
# Processing Record 19 of Set 19 | crailsheim
# Processing Record 20 of Set 19 | novogurovskiy
# Processing Record 21 of Set 19 | alto araguaia
# Processing Record 22 of Set 19 | nanortalik
# Processing Record 23 of Set 19 | shakiso
# Processing Record 24 of Set 19 | walvis bay
# Processing Record 25 of Set 19 | rawson
# Processing Record 26 of Set 19 | kodiak
# Processing Record 27 of Set 19 | puerto ayora
# Processing Record 28 of Set 19 | nikolskoye
# Processing Record 29 of Set 19 | sao filipe
# Processing Record 30 of Set 19 | troitskoye
# Processing Record 31 of Set 19 | cidreira
# Processing Record 32 of Set 19 | batagay
# Processing Record 33 of Set 19 | esna
# Processing Record 34 of Set 19 | ballina
# Processing Record 35 of Set 19 | talnakh
# Processing Record 36 of Set 19 | kysyl-syr
# Processing Record 37 of Set 19 | waddan
# Processing Record 38 of Set 19 | evanston
# Processing Record 39 of Set 19 | cherskiy
# Processing Record 40 of Set 19 | ust-kuyga
# Processing Record 41 of Set 19 | tigil
# Processing Record 42 of Set 19 | jacareacanga
# Processing Record 43 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 19 | chicama
# Processing Record 45 of Set 19 | careiro da varzea
# Processing Record 46 of Set 19 | atuona
# Processing Record 47 of Set 19 | san quintin
# Processing Record 48 of Set 19 | kalmunai
# Processing Record 49 of Set 19 | coquimbo
# Processing Record 50 of Set 19 | muroto
# Processing Record 1 of Set 20 | wazzan
# City not found. Skipping...
# Processing Record 2 of Set 20 | acajutla
# Processing Record 3 of Set 20 | mikuni
# Processing Record 4 of Set 20 | hamilton
# Processing Record 5 of Set 20 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 20 | hoganas
# Processing Record 7 of Set 20 | arlit
# Processing Record 8 of Set 20 | hobart
# Processing Record 9 of Set 20 | akhtubinsk
# Processing Record 10 of Set 20 | bossembele
# City not found. Skipping...
# Processing Record 11 of Set 20 | mogilno
# Processing Record 12 of Set 20 | agirish
# Processing Record 13 of Set 20 | hailey
# Processing Record 14 of Set 20 | honiara
# Processing Record 15 of Set 20 | todos santos
# Processing Record 16 of Set 20 | kaitangata
# Processing Record 17 of Set 20 | sioux lookout
# Processing Record 18 of Set 20 | gizo
# Processing Record 19 of Set 20 | pawak
# Processing Record 20 of Set 20 | lata
# Processing Record 21 of Set 20 | beira
# Processing Record 22 of Set 20 | liwale
# Processing Record 23 of Set 20 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 20 | alexandria
# Processing Record 25 of Set 20 | ubatuba
# Processing Record 26 of Set 20 | lasa
# Processing Record 27 of Set 20 | kavieng
# Processing Record 28 of Set 20 | mtwara
# Processing Record 29 of Set 20 | narsaq
# Processing Record 30 of Set 20 | saldanha
# Processing Record 31 of Set 20 | kargil
# Processing Record 32 of Set 20 | knysna
# Processing Record 33 of Set 20 | bosaso
# Processing Record 34 of Set 20 | luis correia
# Processing Record 35 of Set 20 | sanski most
# Processing Record 36 of Set 20 | samarai
# Processing Record 37 of Set 20 | bairiki
# Processing Record 38 of Set 20 | ahipara
# Processing Record 39 of Set 20 | ulladulla
# Processing Record 40 of Set 20 | madison
# Processing Record 41 of Set 20 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 20 | bucerias
# Processing Record 43 of Set 20 | santa cruz
# Processing Record 44 of Set 20 | lompoc
# Processing Record 45 of Set 20 | moron
# Processing Record 46 of Set 20 | torbay
# Processing Record 47 of Set 20 | warud
# Processing Record 48 of Set 20 | aripuana
# Processing Record 49 of Set 20 | san juan
# Processing Record 50 of Set 20 | dataganj
# Processing Record 1 of Set 21 | nuuk
# Processing Record 2 of Set 21 | pacific grove
# Processing Record 3 of Set 21 | sunagawa
# Processing Record 4 of Set 21 | pisco
# Processing Record 5 of Set 21 | port augusta
# Processing Record 6 of Set 21 | vanavara
# Processing Record 7 of Set 21 | saint-ambroise
# Processing Record 8 of Set 21 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 21 | ambikapur
# Processing Record 10 of Set 21 | yeppoon
# Processing Record 11 of Set 21 | cayenne
# Processing Record 12 of Set 21 | saint george
# Processing Record 13 of Set 21 | urumqi
# Processing Record 14 of Set 21 | faanui
# Processing Record 15 of Set 21 | kazanskaya
# Processing Record 16 of Set 21 | srandakan
# Processing Record 17 of Set 21 | mount gambier
# Processing Record 18 of Set 21 | mogadishu
# Processing Record 19 of Set 21 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 21 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 21 | manokwari
# Processing Record 22 of Set 21 | fort nelson
# Processing Record 23 of Set 21 | huron
# Processing Record 24 of Set 21 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 21 | sao joao da barra
# Processing Record 26 of Set 21 | evensk
# Processing Record 27 of Set 21 | coahuayana
# Processing Record 28 of Set 21 | carman
# Processing Record 29 of Set 21 | esperance
# Processing Record 30 of Set 21 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 21 | kambove
# Processing Record 32 of Set 21 | longyearbyen
# Processing Record 33 of Set 21 | provideniya
# Processing Record 34 of Set 21 | aklavik
# Processing Record 35 of Set 21 | puerto maldonado
# Processing Record 36 of Set 21 | inhambupe
# Processing Record 37 of Set 21 | horki
# Processing Record 38 of Set 21 | malakal
# Processing Record 39 of Set 21 | port blair
# Processing Record 40 of Set 21 | likasi
# Processing Record 41 of Set 21 | gat
# Processing Record 42 of Set 21 | rawlins
# Processing Record 43 of Set 21 | ostrovnoy
# Processing Record 44 of Set 21 | nome
# Processing Record 45 of Set 21 | san sebastian
# Processing Record 46 of Set 21 | beaverlodge
# Processing Record 47 of Set 21 | agutaya
# Processing Record 48 of Set 21 | college
# Processing Record 49 of Set 21 | zhanaozen
# Processing Record 50 of Set 21 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 22 | luderitz
# Processing Record 2 of Set 22 | ajtos
# Processing Record 3 of Set 22 | myitkyina
# Processing Record 4 of Set 22 | vostok
# Processing Record 5 of Set 22 | kirkcudbright
# Processing Record 6 of Set 22 | sainte-maxime
# Processing Record 7 of Set 22 | gogrial
# Processing Record 8 of Set 22 | scarborough
# Processing Record 9 of Set 22 | bubaque
# Processing Record 10 of Set 22 | rio claro
# Processing Record 11 of Set 22 | teknaf
# Processing Record 12 of Set 22 | ginir
# Processing Record 13 of Set 22 | havoysund
# Processing Record 14 of Set 22 | inhambane
# Processing Record 15 of Set 22 | tagusao
# Processing Record 16 of Set 22 | tomatlan
# Processing Record 17 of Set 22 | gazli
# Processing Record 18 of Set 22 | tlacotepec
# Processing Record 19 of Set 22 | salinopolis
# Processing Record 20 of Set 22 | half moon bay
# Processing Record 21 of Set 22 | nouadhibou
# Processing Record 22 of Set 22 | del rio
# Processing Record 23 of Set 22 | khani
# Processing Record 24 of Set 22 | zhashkiv
# Processing Record 25 of Set 22 | diego de almagro
# Processing Record 26 of Set 22 | luanda
# Processing Record 27 of Set 22 | youghal
# Processing Record 28 of Set 22 | velasco ibarra
# Processing Record 29 of Set 22 | omboue
# Processing Record 30 of Set 22 | chokurdakh
# Processing Record 31 of Set 22 | quatre cocos
# Processing Record 32 of Set 22 | zhoukou
# Processing Record 33 of Set 22 | codrington
# Processing Record 34 of Set 22 | souillac
# Processing Record 35 of Set 22 | pochutla
# Processing Record 36 of Set 22 | jeremie
# Processing Record 37 of Set 22 | asau
# Processing Record 38 of Set 22 | salamiyah
# Processing Record 39 of Set 22 | tiksi
# Processing Record 40 of Set 22 | san cristobal
# Processing Record 41 of Set 22 | cabo san lucas
# Processing Record 42 of Set 22 | touros
# Processing Record 43 of Set 22 | san patricio
# Processing Record 44 of Set 22 | manadhoo
# Processing Record 45 of Set 22 | vieques
# Processing Record 46 of Set 22 | sola
# Processing Record 47 of Set 22 | zhaotong
# Processing Record 48 of Set 22 | matara
# Processing Record 49 of Set 22 | mahon
# Processing Record 50 of Set 22 | netivot
# Processing Record 1 of Set 23 | pasighat
# Processing Record 2 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 23 | mukhen
# Processing Record 4 of Set 23 | komsomolskoye
# Processing Record 5 of Set 23 | luang prabang
# Processing Record 6 of Set 23 | along
# Processing Record 7 of Set 23 | alyangula
# Processing Record 8 of Set 23 | te anau
# Processing Record 9 of Set 23 | araouane
# Processing Record 10 of Set 23 | port hawkesbury
# Processing Record 11 of Set 23 | sungaipenuh
# Processing Record 12 of Set 23 | paamiut
# Processing Record 13 of Set 23 | lavrentiya
# Processing Record 14 of Set 23 | gallup
# Processing Record 15 of Set 23 | dalbandin
# Processing Record 16 of Set 23 | juybar
# Processing Record 17 of Set 23 | aras
# Processing Record 18 of Set 23 | georgetown
# Processing Record 19 of Set 23 | sagua la grande
# Processing Record 20 of Set 23 | xining
# Processing Record 21 of Set 23 | dalby
# Processing Record 22 of Set 23 | ayan
# Processing Record 23 of Set 23 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 23 | marshall
# Processing Record 25 of Set 23 | dakoro
# Processing Record 26 of Set 23 | klaksvik
# Processing Record 27 of Set 23 | nizhniy odes
# Processing Record 28 of Set 23 | dunedin
# Processing Record 29 of Set 23 | puerto madryn
# Processing Record 30 of Set 23 | norman wells
# Processing Record 31 of Set 23 | suda
# Processing Record 32 of Set 23 | kouroussa
# Processing Record 33 of Set 23 | christchurch
# Processing Record 34 of Set 23 | eaglesham
# Processing Record 35 of Set 23 | morant bay
# Processing Record 36 of Set 23 | nyzhni sirohozy
# Processing Record 37 of Set 23 | vardo
# Processing Record 38 of Set 23 | rudbar
# Processing Record 39 of Set 23 | blagoveshchensk
# Processing Record 40 of Set 23 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 23 | iralaya
# Processing Record 42 of Set 23 | bafq
# Processing Record 43 of Set 23 | vila franca do campo
# Processing Record 44 of Set 23 | atar
# Processing Record 45 of Set 23 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 23 | mount pleasant
# Processing Record 47 of Set 23 | wenzhou
# Processing Record 48 of Set 23 | aswan
# Processing Record 49 of Set 23 | mukhtolovo
# Processing Record 50 of Set 23 | plettenberg bay
# Processing Record 1 of Set 24 | mangile
# City not found. Skipping...
# Processing Record 2 of Set 24 | macon
# Processing Record 3 of Set 24 | wagar
# Processing Record 4 of Set 24 | constitucion
# Processing Record 5 of Set 24 | kununurra
# Processing Record 6 of Set 24 | mwinilunga
# Processing Record 7 of Set 24 | baijiantan
# Processing Record 8 of Set 24 | kasiri
# Processing Record 9 of Set 24 | lovozero
# Processing Record 10 of Set 24 | alashtar
# City not found. Skipping...
# Processing Record 11 of Set 24 | hammerfest
# Processing Record 12 of Set 24 | zlobin
# Processing Record 13 of Set 24 | lexington park
# Processing Record 14 of Set 24 | hami
# Processing Record 15 of Set 24 | grootfontein
# Processing Record 16 of Set 24 | pastavy
# Processing Record 17 of Set 24 | angoche
# Processing Record 18 of Set 24 | lethem
# Processing Record 19 of Set 24 | keuruu
# Processing Record 20 of Set 24 | quthing
# Processing Record 21 of Set 24 | belle glade
# Processing Record 22 of Set 24 | puerto narino
# Processing Record 23 of Set 24 | altamira
# Processing Record 24 of Set 24 | charters towers
# Processing Record 25 of Set 24 | gamba
# Processing Record 26 of Set 24 | nanakuli
# Processing Record 27 of Set 24 | san rafael
# Processing Record 28 of Set 24 | davila
# Processing Record 29 of Set 24 | jos
# Processing Record 30 of Set 24 | maiduguri
# Processing Record 31 of Set 24 | monte cristi
# City not found. Skipping...
# Processing Record 32 of Set 24 | bayanday
# Processing Record 33 of Set 24 | garissa
# Processing Record 34 of Set 24 | fairbanks
# Processing Record 35 of Set 24 | benguela
# Processing Record 36 of Set 24 | sobolevo
# Processing Record 37 of Set 24 | tortoli
# Processing Record 38 of Set 24 | rio verde de mato grosso
# Processing Record 39 of Set 24 | porterville
# Processing Record 40 of Set 24 | armidale
# Processing Record 41 of Set 24 | sapele
# Processing Record 42 of Set 24 | sri aman
# Processing Record 43 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 24 | oranjemund
# Processing Record 45 of Set 24 | diapaga
# Processing Record 46 of Set 24 | sines
# Processing Record 47 of Set 24 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 24 | villa rica
# Processing Record 49 of Set 24 | buckeye
# Processing Record 50 of Set 24 | murgab
# Processing Record 1 of Set 25 | kabompo
# Processing Record 2 of Set 25 | roald
# Processing Record 3 of Set 25 | hamadan
# Processing Record 4 of Set 25 | heihe
# Processing Record 5 of Set 25 | palu
# Processing Record 6 of Set 25 | jalingo
# Processing Record 7 of Set 25 | ziro
# Processing Record 8 of Set 25 | iquique
# Processing Record 9 of Set 25 | jalu
# Processing Record 10 of Set 25 | taft
# Processing Record 11 of Set 25 | preobrazheniye
# Processing Record 12 of Set 25 | balaipungut
# Processing Record 13 of Set 25 | poum
# Processing Record 14 of Set 25 | baykit
# Processing Record 15 of Set 25 | yangambi
# Processing Record 16 of Set 25 | iskateley
# Processing Record 17 of Set 25 | verkhoyansk
# Processing Record 18 of Set 25 | bilibino
# Processing Record 19 of Set 25 | kathu
# Processing Record 20 of Set 25 | bakchar
# Processing Record 21 of Set 25 | virginia beach
# Processing Record 22 of Set 25 | mayo
# Processing Record 23 of Set 25 | gewane
# Processing Record 24 of Set 25 | nisia floresta
# Processing Record 25 of Set 25 | bloemfontein
# Processing Record 26 of Set 25 | santo antonio do ica
# Processing Record 27 of Set 25 | misratah
# Processing Record 28 of Set 25 | victor harbor
# Processing Record 29 of Set 25 | ryotsu
# Processing Record 30 of Set 25 | lorengau
# Processing Record 31 of Set 25 | zemetchino
# Processing Record 32 of Set 25 | cabra
# Processing Record 33 of Set 25 | denau
# City not found. Skipping...
# Processing Record 34 of Set 25 | pontes e lacerda
# Processing Record 35 of Set 25 | sayyan
# Processing Record 36 of Set 25 | saint-joseph
# Processing Record 37 of Set 25 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 25 | nara
# Processing Record 39 of Set 25 | nizhniy kuranakh
# Processing Record 40 of Set 25 | oktyabrskoye
# Processing Record 41 of Set 25 | saint anthony
# Processing Record 42 of Set 25 | oyotun
# Processing Record 43 of Set 25 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 25 | ahuimanu
# Processing Record 45 of Set 25 | mahaicony
# City not found. Skipping...
# Processing Record 46 of Set 25 | ajdabiya
# Processing Record 47 of Set 25 | codajas
# Processing Record 48 of Set 25 | hofn
# Processing Record 49 of Set 25 | casablanca
# Processing Record 50 of Set 25 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 26 | husavik
# Processing Record 2 of Set 26 | kodigenahalli
# Processing Record 3 of Set 26 | santa maria
# Processing Record 4 of Set 26 | marrakesh
# Processing Record 5 of Set 26 | itarantim
# Processing Record 6 of Set 26 | kirovskiy
# Processing Record 7 of Set 26 | nhulunbuy
# Processing Record 8 of Set 26 | camacha
# Processing Record 9 of Set 26 | garowe
# Processing Record 10 of Set 26 | mandalgovi
# Processing Record 11 of Set 26 | yar-sale
# Processing Record 12 of Set 26 | damietta
# Processing Record 13 of Set 26 | chiredzi
# Processing Record 14 of Set 26 | cheyenne
# Processing Record 15 of Set 26 | salisbury
# Processing Record 16 of Set 26 | pangai
# Processing Record 17 of Set 26 | abashiri
# Processing Record 18 of Set 26 | baker city
# Processing Record 19 of Set 26 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 26 | nevel
# Processing Record 21 of Set 26 | hambantota
# Processing Record 22 of Set 26 | kargopol
# Processing Record 23 of Set 26 | pishin
# Processing Record 24 of Set 26 | shiringushi
# Processing Record 25 of Set 26 | egvekinot
# Processing Record 26 of Set 26 | berlevag
# Processing Record 27 of Set 26 | sao jose da coroa grande
# Processing Record 28 of Set 26 | mantua
# Processing Record 29 of Set 26 | ziniare
# Processing Record 30 of Set 26 | talas
# Processing Record 31 of Set 26 | kruisfontein
# Processing Record 32 of Set 26 | spearfish
# Processing Record 33 of Set 26 | tres passos
# Processing Record 34 of Set 26 | brewster
# Processing Record 35 of Set 26 | ivanava
# Processing Record 36 of Set 26 | lerwick
# Processing Record 37 of Set 26 | alzey
# Processing Record 38 of Set 26 | itarema
# Processing Record 39 of Set 26 | chapada dos guimaraes
# Processing Record 40 of Set 26 | alta floresta
# Processing Record 41 of Set 26 | jilin
# Processing Record 42 of Set 26 | yaan
# Processing Record 43 of Set 26 | pangody
# Processing Record 44 of Set 26 | bagdarin
# Processing Record 45 of Set 26 | poya
# Processing Record 46 of Set 26 | mehamn
# Processing Record 47 of Set 26 | keti bandar
# Processing Record 48 of Set 26 | albolote
# Processing Record 49 of Set 26 | alofi
# Processing Record 50 of Set 26 | bodden town
# Processing Record 1 of Set 27 | taraza
# Processing Record 2 of Set 27 | venice
# Processing Record 3 of Set 27 | myski
# Processing Record 4 of Set 27 | we
# City not found. Skipping...
# Processing Record 5 of Set 27 | namibe
# Processing Record 6 of Set 27 | westport
# Processing Record 7 of Set 27 | mandurah
# Processing Record 8 of Set 27 | vanimo
# Processing Record 9 of Set 27 | prainha
# Processing Record 10 of Set 27 | najran
# Processing Record 11 of Set 27 | jurbarkas
# Processing Record 12 of Set 27 | vung tau
# Processing Record 13 of Set 27 | katav-ivanovsk
# Processing Record 14 of Set 27 | kailua
# Processing Record 15 of Set 27 | malanje
# Processing Record 16 of Set 27 | miri
# Processing Record 17 of Set 27 | nishihara
# Processing Record 18 of Set 27 | turbat
# Processing Record 19 of Set 27 | martil
# Processing Record 20 of Set 27 | zeya
# Processing Record 21 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 27 | ridgecrest
# Processing Record 23 of Set 27 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 27 | road town
# Processing Record 25 of Set 27 | mlawa
# Processing Record 26 of Set 27 | sal rei
# Processing Record 27 of Set 27 | bousso
# Processing Record 28 of Set 27 | san policarpo
# Processing Record 29 of Set 27 | shimoda
# Processing Record 30 of Set 27 | kachug
# Processing Record 31 of Set 27 | san ignacio
# Processing Record 32 of Set 27 | fairlie
# Processing Record 33 of Set 27 | bathsheba
# Processing Record 34 of Set 27 | goma
# Processing Record 35 of Set 27 | finnsnes
# Processing Record 36 of Set 27 | merauke
# Processing Record 37 of Set 27 | choya
# Processing Record 38 of Set 27 | naze
# Processing Record 39 of Set 27 | sarakhs
# Processing Record 40 of Set 27 | istra
# Processing Record 41 of Set 27 | puerto escondido
# Processing Record 42 of Set 27 | padang
# Processing Record 43 of Set 27 | chadiza
# Processing Record 44 of Set 27 | stanari
# Processing Record 45 of Set 27 | caruray
# Processing Record 46 of Set 27 | cabrobo
# Processing Record 47 of Set 27 | mugumu
# Processing Record 48 of Set 27 | muri
# Processing Record 49 of Set 27 | alenquer
# Processing Record 50 of Set 27 | beja
# Processing Record 1 of Set 28 | tandil
# Processing Record 2 of Set 28 | praia
# Processing Record 3 of Set 28 | lazaro cardenas
# Processing Record 4 of Set 28 | nelson bay
# Processing Record 5 of Set 28 | whitianga
# Processing Record 6 of Set 28 | chandla
# Processing Record 7 of Set 28 | monrovia
# Processing Record 8 of Set 28 | kot samaba
# Processing Record 9 of Set 28 | loralai
# Processing Record 10 of Set 28 | hukuntsi
# Processing Record 11 of Set 28 | henties bay
# Processing Record 12 of Set 28 | north auburn
# Processing Record 13 of Set 28 | lyngseidet
# Processing Record 14 of Set 28 | kokstad
# Processing Record 15 of Set 28 | khovu-aksy
# Processing Record 16 of Set 28 | port hedland
# Processing Record 17 of Set 28 | saint-felicien
# Processing Record 18 of Set 28 | porto novo
# Processing Record 19 of Set 28 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 28 | sandwick
# Processing Record 21 of Set 28 | bambanglipuro
# Processing Record 22 of Set 28 | olinda
# Processing Record 23 of Set 28 | gondanglegi
# Processing Record 24 of Set 28 | lleida
# Processing Record 25 of Set 28 | traverse city
# Processing Record 26 of Set 28 | aksu
# Processing Record 27 of Set 28 | rorvik
# Processing Record 28 of Set 28 | boulder city
# Processing Record 29 of Set 28 | tanjong sepat
# City not found. Skipping...
# Processing Record 30 of Set 28 | alamogordo
# Processing Record 31 of Set 28 | maloshuyka
# City not found. Skipping...
# Processing Record 32 of Set 28 | zavodoukovsk
# Processing Record 33 of Set 28 | yatou
# Processing Record 34 of Set 28 | inta
# Processing Record 35 of Set 28 | kulhudhuffushi
# Processing Record 36 of Set 28 | suffolk
# Processing Record 37 of Set 28 | moree
# Processing Record 38 of Set 28 | azimur
# City not found. Skipping...
# Processing Record 39 of Set 28 | geraldton
# Processing Record 40 of Set 28 | mocajuba
# Processing Record 41 of Set 28 | mildura
# Processing Record 42 of Set 28 | axim
# Processing Record 43 of Set 28 | katangli
# Processing Record 44 of Set 28 | xacmaz
# Processing Record 45 of Set 28 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 28 | north platte
# Processing Record 47 of Set 28 | minbu
# Processing Record 48 of Set 28 | arraias
# Processing Record 49 of Set 28 | acarau
# Processing Record 50 of Set 28 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 29 | novyy urgal
# Processing Record 2 of Set 29 | nagorsk
# Processing Record 3 of Set 29 | ngama
# Processing Record 4 of Set 29 | novoomskiy
# Processing Record 5 of Set 29 | kualakapuas
# Processing Record 6 of Set 29 | galle
# Processing Record 7 of Set 29 | alice springs
# Processing Record 8 of Set 29 | amapa
# Processing Record 9 of Set 29 | council bluffs
# Processing Record 10 of Set 29 | agadez
# Processing Record 11 of Set 29 | chapais
# Processing Record 12 of Set 29 | adilcevaz
# Processing Record 13 of Set 29 | mitoc
# Processing Record 14 of Set 29 | harrismith
# Processing Record 15 of Set 29 | yarmouth
# Processing Record 16 of Set 29 | beausejour
# Processing Record 17 of Set 29 | pevek
# Processing Record 18 of Set 29 | lensk
# Processing Record 19 of Set 29 | deputatskiy
# Processing Record 20 of Set 29 | karpinsk
# Processing Record 21 of Set 29 | maarianhamina
# Processing Record 22 of Set 29 | pemberton
# Processing Record 23 of Set 29 | harper
# Processing Record 24 of Set 29 | usinsk
# Processing Record 25 of Set 29 | ozgon
# City not found. Skipping...
# Processing Record 26 of Set 29 | ciras
# City not found. Skipping...
# Processing Record 27 of Set 29 | soyo
# Processing Record 28 of Set 29 | anahuac
# Processing Record 29 of Set 29 | neka
# Processing Record 30 of Set 29 | kampot
# Processing Record 31 of Set 29 | lukovetskiy
# Processing Record 32 of Set 29 | praya
# Processing Record 33 of Set 29 | lulea
# Processing Record 34 of Set 29 | batagay-alyta
# Processing Record 35 of Set 29 | tessalit
# Processing Record 36 of Set 29 | jaciara
# Processing Record 37 of Set 29 | ancud
# Processing Record 38 of Set 29 | rudnogorsk
# Processing Record 39 of Set 29 | antofagasta
# Processing Record 40 of Set 29 | maunabo
# Processing Record 41 of Set 29 | itoigawa
# Processing Record 42 of Set 29 | northam
# Processing Record 43 of Set 29 | okakarara
# Processing Record 44 of Set 29 | reynosa
# Processing Record 45 of Set 29 | thunder bay
# Processing Record 46 of Set 29 | turukhansk
# Processing Record 47 of Set 29 | kuusamo
# Processing Record 48 of Set 29 | payson
# Processing Record 49 of Set 29 | birjand
# Processing Record 50 of Set 29 | akonolinga
# Processing Record 1 of Set 30 | bougouni
# Processing Record 2 of Set 30 | biak
# Processing Record 3 of Set 30 | sierpc
# Processing Record 4 of Set 30 | rajula
# Processing Record 5 of Set 30 | sechura
# Processing Record 6 of Set 30 | ilyich
# Processing Record 7 of Set 30 | flinders
# Processing Record 8 of Set 30 | verkhniy fiagdon
# Processing Record 9 of Set 30 | belaya gora
# Processing Record 10 of Set 30 | sabzevar
# Processing Record 11 of Set 30 | nijar
# Processing Record 12 of Set 30 | sisimiut
# Processing Record 13 of Set 30 | marevo
# Processing Record 14 of Set 30 | dekoa
# City not found. Skipping...
# Processing Record 15 of Set 30 | kastamonu
# Processing Record 16 of Set 30 | erenhot
# Processing Record 17 of Set 30 | saryozek
# Processing Record 18 of Set 30 | juneau
# Processing Record 19 of Set 30 | nehe
# Processing Record 20 of Set 30 | pringsewu
# Processing Record 21 of Set 30 | manavgat
# Processing Record 22 of Set 30 | troitsk
# Processing Record 23 of Set 30 | key west
# Processing Record 24 of Set 30 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 30 | isangel
# Processing Record 26 of Set 30 | grandview
# Processing Record 27 of Set 30 | chany
# Processing Record 28 of Set 30 | dwarka
# Processing Record 29 of Set 30 | aykhal
# Processing Record 30 of Set 30 | ikalamavony
# Processing Record 31 of Set 30 | tambovka
# Processing Record 32 of Set 30 | agadir
# Processing Record 33 of Set 30 | bacuit
# City not found. Skipping...
# Processing Record 34 of Set 30 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 30 | nybro
# Processing Record 36 of Set 30 | rocha
# Processing Record 37 of Set 30 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 30 | puerto madero
# Processing Record 39 of Set 30 | sterling
# Processing Record 40 of Set 30 | santiago
# Processing Record 41 of Set 30 | voznesenye
# Processing Record 42 of Set 30 | ballinasloe
# Processing Record 43 of Set 30 | esil
# Processing Record 44 of Set 30 | orocue
# Processing Record 45 of Set 30 | maragogi
# Processing Record 46 of Set 30 | ambilobe
# Processing Record 47 of Set 30 | the valley
# Processing Record 48 of Set 30 | beloha
# Processing Record 49 of Set 30 | khandyga
# Processing Record 50 of Set 30 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 31 | sile
# Processing Record 2 of Set 31 | vila velha
# Processing Record 3 of Set 31 | babakan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Run an API request for each of the cities.
my_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=079f43442134212973786a277a29ecad&q=appleton"
# Parse the JSON and retrieve data.
city_weather = requests.get(my_url).json()

report = city_weather["weather"]
weather_description = report[0]['description']

weather_description
# Out:
# 'clear sky'

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
vacation_city_data_df = pd.DataFrame(city_data)
vacation_city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kavaratti  10.5669   72.6420     81.68        66           0
# 1          Emirdag  39.0197   31.1500     53.91        42          82
# 2  Arraial Do Cabo -22.9661  -42.0278     77.00        83          75
# 3           Barrow  71.2906 -156.7887    -18.40        69           1
# 4          Rikitea -23.1203 -134.9692     77.20        73          95
# 5        Belogorsk  50.9158  128.4611    -15.16        87           0
# 6           Albany  42.6001  -73.9662     24.01       100          90
# 7             Hilo  19.7297 -155.0900     64.40        59          20
# 8   Port Elizabeth -33.9180   25.5701     68.00        94          75
# 9          Ushuaia -54.8000  -68.3000     59.00        55           0
#
#    Wind Speed Country    Description
# 0        7.31      IN      clear sky
# 1       10.49      TR  broken clouds
# 2        9.22      BR  moderate rain
# 3       11.50      US     light snow
# 4       11.45      PF     light rain
# 5        7.99      RU      clear sky
# 6        3.44      US           snow
# 7        8.05      US     few clouds
# 8        9.22      ZA  broken clouds
# 9       13.80      AR      clear sky

# %%
 new_column_order = ["City", "Country", "Description", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
vacation_city_data_df = vacation_city_data_df[new_column_order]
vacation_city_data_df
# Out:
#                 City Country           Description      Lat       Lng  \
# 0          Kavaratti      IN             clear sky  10.5669   72.6420
# 1            Emirdag      TR         broken clouds  39.0197   31.1500
# 2    Arraial Do Cabo      BR         moderate rain -22.9661  -42.0278
# 3             Barrow      US            light snow  71.2906 -156.7887
# 4            Rikitea      PF            light rain -23.1203 -134.9692
# ..               ...     ...                   ...      ...       ...
# 688           Beloha      MG      scattered clouds -25.1667   45.0500
# 689         Khandyga      RU      scattered clouds  62.6667  135.6000
# 690             Sile      TR             clear sky  41.1754   29.6133
# 691       Vila Velha      BR  heavy intensity rain -20.3297  -40.2925
# 692          Babakan      ID       overcast clouds  -7.2820  107.2224
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       81.68        66           0        7.31
# 1       53.91        42          82       10.49
# 2       77.00        83          75        9.22
# 3      -18.40        69           1       11.50
# 4       77.20        73          95       11.45
# ..        ...       ...         ...         ...
# 688     78.85        75          29       11.36
# 689    -34.17        82          28        2.64
# 690     60.80        59           0        2.30
# 691     70.00       100          90        2.30
# 692     74.03        80         100        6.29
#
# [693 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the WeatherPy_Database into a CSV.
vacation_city_data_df.to_csv(output_data_file)
